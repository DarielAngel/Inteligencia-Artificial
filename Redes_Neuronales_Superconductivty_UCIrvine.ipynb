# %% [markdown]
# <a href="https://colab.research.google.com/github/DarielAngel/Inteligencia-Artificial/blob/main/Redes_Neuronales_Superconductivty_UCIrvine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install -U ucimlrepo
# Out:
# Collecting ucimlrepo
#   Downloading ucimlrepo-0.0.7-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ucimlrepo) (2.2.2)
# Requirement already satisfied: certifi>=2020.12.5 in /usr/local/lib/python3.11/dist-packages (from ucimlrepo) (2024.12.14)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->ucimlrepo) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->ucimlrepo) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->ucimlrepo) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->ucimlrepo) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->ucimlrepo) (1.17.0)
# Downloading ucimlrepo-0.0.7-py3-none-any.whl (8.0 kB)
# Installing collected packages: ucimlrepo
# Successfully installed ucimlrepo-0.0.7

# %%
from ucimlrepo import fetch_ucirepo, list_available_datasets

# check which datasets can be imported
#list_available_datasets()

superconductivty = fetch_ucirepo(id=464)

print(superconductivty)
# Out:
# {'data': {'ids': None, 'features':        number_of_elements  mean_atomic_mass  wtd_mean_atomic_mass  \
# 0                       4         88.944468             57.862692
# 1                       5         92.729214             58.518416
# 2                       4         88.944468             57.885242
# 3                       4         88.944468             57.873967
# 4                       4         88.944468             57.840143
# ...                   ...               ...                   ...
# 21258                   4        106.957877             53.095769
# 21259                   5         92.266740             49.021367
# 21260                   2         99.663190             95.609104
# 21261                   2         99.663190             97.095602
# 21262                   3         87.468333             86.858500
#
#        gmean_atomic_mass  wtd_gmean_atomic_mass  entropy_atomic_mass  \
# 0              66.361592              36.116612             1.181795
# 1              73.132787              36.396602             1.449309
# 2              66.361592              36.122509             1.181795
# 3              66.361592              36.119560             1.181795
# 4              66.361592              36.110716             1.181795
# ...                  ...                    ...                  ...
# 21258          82.515384              43.135565             1.177145
# 21259          64.812662              32.867748             1.323287
# 21260          99.433882              95.464320             0.690847
# 21261          99.433882              96.901083             0.690847
# 21262          82.555758              80.458722             1.041270
#
#        wtd_entropy_atomic_mass  range_atomic_mass  wtd_range_atomic_mass  \
# 0                     1.062396          122.90607              31.794921
# 1                     1.057755          122.90607              36.161939
# 2                     0.975980          122.90607              35.741099
# 3                     1.022291          122.90607              33.768010
# 4                     1.129224          122.90607              27.848743
# ...                        ...                ...                    ...
# 21258                 1.254119          146.88130              15.504479
# 21259                 1.571630          188.38390               7.353333
# 21260                 0.530198           13.51362              53.041104
# 21261                 0.640883           13.51362              31.115202
# 21262                 0.895229           71.75500              43.144000
#
#        std_atomic_mass  ...  mean_Valence  wtd_mean_Valence  gmean_Valence  \
# 0            51.968828  ...          2.25          2.257143       2.213364
# 1            47.094633  ...          2.00          2.257143       1.888175
# 2            51.968828  ...          2.25          2.271429       2.213364
# 3            51.968828  ...          2.25          2.264286       2.213364
# 4            51.968828  ...          2.25          2.242857       2.213364
# ...                ...  ...           ...               ...            ...
# 21258        65.764081  ...          3.25          3.555556       3.223710
# 21259        69.232655  ...          2.20          2.047619       2.168944
# 21260         6.756810  ...          4.50          4.800000       4.472136
# 21261         6.756810  ...          4.50          4.690000       4.472136
# 21262        29.905282  ...          5.00          4.500000       4.762203
#
#        wtd_gmean_Valence  entropy_Valence  wtd_entropy_Valence  range_Valence  \
# 0               2.219783         1.368922             1.066221              1
# 1               2.210679         1.557113             1.047221              2
# 2               2.232679         1.368922             1.029175              1
# 3               2.226222         1.368922             1.048834              1
# 4               2.206963         1.368922             1.096052              1
# ...                  ...              ...                  ...            ...
# 21258           3.519911         1.377820             0.913658              1
# 21259           2.038991         1.594167             1.337246              1
# 21260           4.781762         0.686962             0.450561              1
# 21261           4.665819         0.686962             0.577601              1
# 21262           4.242641         1.054920             0.970116              3
#
#        wtd_range_Valence  std_Valence  wtd_std_Valence
# 0               1.085714     0.433013         0.437059
# 1               1.128571     0.632456         0.468606
# 2               1.114286     0.433013         0.444697
# 3               1.100000     0.433013         0.440952
# 4               1.057143     0.433013         0.428809
# ...                  ...          ...              ...
# 21258           2.168889     0.433013         0.496904
# 21259           0.904762     0.400000         0.212959
# 21260           3.200000     0.500000         0.400000
# 21261           2.210000     0.500000         0.462493
# 21262           1.800000     1.414214         1.500000
#
# [21263 rows x 81 columns], 'targets':        critical_temp
# 0              29.00
# 1              26.00
# 2              19.00
# 3              22.00
# 4              23.00
# ...              ...
# 21258           2.44
# 21259         122.10
# 21260           1.98
# 21261           1.84
# 21262          12.80
#
# [21263 rows x 1 columns], 'original':        number_of_elements  mean_atomic_mass  wtd_mean_atomic_mass  \
# 0                       4         88.944468             57.862692
# 1                       5         92.729214             58.518416
# 2                       4         88.944468             57.885242
# 3                       4         88.944468             57.873967
# 4                       4         88.944468             57.840143
# ...                   ...               ...                   ...
# 21258                   4        106.957877             53.095769
# 21259                   5         92.266740             49.021367
# 21260                   2         99.663190             95.609104
# 21261                   2         99.663190             97.095602
# 21262                   3         87.468333             86.858500
#
#        gmean_atomic_mass  wtd_gmean_atomic_mass  entropy_atomic_mass  \
# 0              66.361592              36.116612             1.181795
# 1              73.132787              36.396602             1.449309
# 2              66.361592              36.122509             1.181795
# 3              66.361592              36.119560             1.181795
# 4              66.361592              36.110716             1.181795
# ...                  ...                    ...                  ...
# 21258          82.515384              43.135565             1.177145
# 21259          64.812662              32.867748             1.323287
# 21260          99.433882              95.464320             0.690847
# 21261          99.433882              96.901083             0.690847
# 21262          82.555758              80.458722             1.041270
#
#        wtd_entropy_atomic_mass  range_atomic_mass  wtd_range_atomic_mass  \
# 0                     1.062396          122.90607              31.794921
# 1                     1.057755          122.90607              36.161939
# 2                     0.975980          122.90607              35.741099
# 3                     1.022291          122.90607              33.768010
# 4                     1.129224          122.90607              27.848743
# ...                        ...                ...                    ...
# 21258                 1.254119          146.88130              15.504479
# 21259                 1.571630          188.38390               7.353333
# 21260                 0.530198           13.51362              53.041104
# 21261                 0.640883           13.51362              31.115202
# 21262                 0.895229           71.75500              43.144000
#
#        std_atomic_mass  ...  wtd_mean_Valence  gmean_Valence  \
# 0            51.968828  ...          2.257143       2.213364
# 1            47.094633  ...          2.257143       1.888175
# 2            51.968828  ...          2.271429       2.213364
# 3            51.968828  ...          2.264286       2.213364
# 4            51.968828  ...          2.242857       2.213364
# ...                ...  ...               ...            ...
# 21258        65.764081  ...          3.555556       3.223710
# 21259        69.232655  ...          2.047619       2.168944
# 21260         6.756810  ...          4.800000       4.472136
# 21261         6.756810  ...          4.690000       4.472136
# 21262        29.905282  ...          4.500000       4.762203
#
#        wtd_gmean_Valence  entropy_Valence  wtd_entropy_Valence  range_Valence  \
# 0               2.219783         1.368922             1.066221              1
# 1               2.210679         1.557113             1.047221              2
# 2               2.232679         1.368922             1.029175              1
# 3               2.226222         1.368922             1.048834              1
# 4               2.206963         1.368922             1.096052              1
# ...                  ...              ...                  ...            ...
# 21258           3.519911         1.377820             0.913658              1
# 21259           2.038991         1.594167             1.337246              1
# 21260           4.781762         0.686962             0.450561              1
# 21261           4.665819         0.686962             0.577601              1
# 21262           4.242641         1.054920             0.970116              3
#
#        wtd_range_Valence  std_Valence  wtd_std_Valence  critical_temp
# 0               1.085714     0.433013         0.437059          29.00
# 1               1.128571     0.632456         0.468606          26.00
# 2               1.114286     0.433013         0.444697          19.00
# 3               1.100000     0.433013         0.440952          22.00
# 4               1.057143     0.433013         0.428809          23.00
# ...                  ...          ...              ...            ...
# 21258           2.168889     0.433013         0.496904           2.44
# 21259           0.904762     0.400000         0.212959         122.10
# 21260           3.200000     0.500000         0.400000           1.98
# 21261           2.210000     0.500000         0.462493           1.84
# 21262           1.800000     1.414214         1.500000          12.80
#
# [21263 rows x 82 columns], 'headers': Index(['number_of_elements', 'mean_atomic_mass', 'wtd_mean_atomic_mass',
#        'gmean_atomic_mass', 'wtd_gmean_atomic_mass', 'entropy_atomic_mass',
#        'wtd_entropy_atomic_mass', 'range_atomic_mass', 'wtd_range_atomic_mass',
#        'std_atomic_mass', 'wtd_std_atomic_mass', 'mean_fie', 'wtd_mean_fie',
#        'gmean_fie', 'wtd_gmean_fie', 'entropy_fie', 'wtd_entropy_fie',
#        'range_fie', 'wtd_range_fie', 'std_fie', 'wtd_std_fie',
#        'mean_atomic_radius', 'wtd_mean_atomic_radius', 'gmean_atomic_radius',
#        'wtd_gmean_atomic_radius', 'entropy_atomic_radius',
#        'wtd_entropy_atomic_radius', 'range_atomic_radius',
#        'wtd_range_atomic_radius', 'std_atomic_radius', 'wtd_std_atomic_radius',
#        'mean_Density', 'wtd_mean_Density', 'gmean_Density',
#        'wtd_gmean_Density', 'entropy_Density', 'wtd_entropy_Density',
#        'range_Density', 'wtd_range_Density', 'std_Density', 'wtd_std_Density',
#        'mean_ElectronAffinity', 'wtd_mean_ElectronAffinity',
#        'gmean_ElectronAffinity', 'wtd_gmean_ElectronAffinity',
#        'entropy_ElectronAffinity', 'wtd_entropy_ElectronAffinity',
#        'range_ElectronAffinity', 'wtd_range_ElectronAffinity',
#        'std_ElectronAffinity', 'wtd_std_ElectronAffinity', 'mean_FusionHeat',
#        'wtd_mean_FusionHeat', 'gmean_FusionHeat', 'wtd_gmean_FusionHeat',
#        'entropy_FusionHeat', 'wtd_entropy_FusionHeat', 'range_FusionHeat',
#        'wtd_range_FusionHeat', 'std_FusionHeat', 'wtd_std_FusionHeat',
#        'mean_ThermalConductivity', 'wtd_mean_ThermalConductivity',
#        'gmean_ThermalConductivity', 'wtd_gmean_ThermalConductivity',
#        'entropy_ThermalConductivity', 'wtd_entropy_ThermalConductivity',
#        'range_ThermalConductivity', 'wtd_range_ThermalConductivity',
#        'std_ThermalConductivity', 'wtd_std_ThermalConductivity',
#        'mean_Valence', 'wtd_mean_Valence', 'gmean_Valence',
#        'wtd_gmean_Valence', 'entropy_Valence', 'wtd_entropy_Valence',
#        'range_Valence', 'wtd_range_Valence', 'std_Valence', 'wtd_std_Valence',
#        'critical_temp'],
#       dtype='object')}, 'metadata': {'uci_id': 464, 'name': 'Superconductivty Data', 'repository_url': 'https://archive.ics.uci.edu/dataset/464/superconductivty+data', 'data_url': 'https://archive.ics.uci.edu/static/public/464/data.csv', 'abstract': 'Two file s contain data on 21263 superconductors and their relevant features.', 'area': 'Physics and Chemistry', 'tasks': ['Regression'], 'characteristics': ['Multivariate'], 'num_instances': 21263, 'num_features': 81, 'feature_types': ['Real'], 'demographics': [], 'target_col': ['critical_temp'], 'index_col': None, 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 2018, 'last_updated': 'Fri Mar 29 2024', 'dataset_doi': '10.24432/C53P47', 'creators': ['Kam Hamidieh'], 'intro_paper': {'ID': 452, 'type': 'NATIVE', 'title': 'A data-driven statistical model for predicting the critical temperature of a superconductor', 'authors': 'K. Hamidieh', 'venue': 'Computational materials science', 'year': 2018, 'journal': None, 'DOI': None, 'URL': 'https://www.semanticscholar.org/paper/A-data-driven-statistical-model-for-predicting-the-Hamidieh/b3bea0ac481f0869cb746f3b44d5689bf1a9b924', 'sha': None, 'corpus': None, 'arxiv': None, 'mag': None, 'acl': None, 'pmid': None, 'pmcid': None}, 'additional_info': {'summary': 'There are two files: (1) train.csv contains 81 features extracted from 21263 superconductors along with the critical temperature in the 82nd column, (2) unique_m.csv contains the chemical formula broken up for all the 21263 superconductors from the train.csv file.  The last two columns have the critical temperature and chemical formula.  The original data comes from http://supercon.nims.go.jp/index_en.html which is public.  The goal here is to predict the critical temperature based on the features extracted.', 'purpose': None, 'funded_by': None, 'instances_represent': None, 'recommended_data_splits': None, 'sensitive_data': None, 'preprocessing_description': None, 'variable_info': 'Please see the relevant paper for the feature explanations.', 'citation': None}}, 'variables':                      name     role        type demographic description units  \
# 0      number_of_elements  Feature     Integer        None        None  None
# 1        mean_atomic_mass  Feature  Continuous        None        None  None
# 2    wtd_mean_atomic_mass  Feature  Continuous        None        None  None
# 3       gmean_atomic_mass  Feature  Continuous        None        None  None
# 4   wtd_gmean_atomic_mass  Feature  Continuous        None        None  None
# ..                    ...      ...         ...         ...         ...   ...
# 77          range_Valence  Feature     Integer        None        None  None
# 78      wtd_range_Valence  Feature  Continuous        None        None  None
# 79            std_Valence  Feature  Continuous        None        None  None
# 80        wtd_std_Valence  Feature  Continuous        None        None  None
# 81          critical_temp   Target     Integer        None        None  None
#
#    missing_values
# 0              no
# 1              no
# 2              no
# 3              no
# 4              no
# ..            ...
# 77             no
# 78             no
# 79             no
# 80             no
# 81             no
#
# [82 rows x 7 columns]}

# %%
print(superconductivty.data.original)
# Out:
#        number_of_elements  mean_atomic_mass  wtd_mean_atomic_mass  \
# 0                       4         88.944468             57.862692
# 1                       5         92.729214             58.518416
# 2                       4         88.944468             57.885242
# 3                       4         88.944468             57.873967
# 4                       4         88.944468             57.840143
# ...                   ...               ...                   ...
# 21258                   4        106.957877             53.095769
# 21259                   5         92.266740             49.021367
# 21260                   2         99.663190             95.609104
# 21261                   2         99.663190             97.095602
# 21262                   3         87.468333             86.858500
#
#        gmean_atomic_mass  wtd_gmean_atomic_mass  entropy_atomic_mass  \
# 0              66.361592              36.116612             1.181795
# 1              73.132787              36.396602             1.449309
# 2              66.361592              36.122509             1.181795
# 3              66.361592              36.119560             1.181795
# 4              66.361592              36.110716             1.181795
# ...                  ...                    ...                  ...
# 21258          82.515384              43.135565             1.177145
# 21259          64.812662              32.867748             1.323287
# 21260          99.433882              95.464320             0.690847
# 21261          99.433882              96.901083             0.690847
# 21262          82.555758              80.458722             1.041270
#
#        wtd_entropy_atomic_mass  range_atomic_mass  wtd_range_atomic_mass  \
# 0                     1.062396          122.90607              31.794921
# 1                     1.057755          122.90607              36.161939
# 2                     0.975980          122.90607              35.741099
# 3                     1.022291          122.90607              33.768010
# 4                     1.129224          122.90607              27.848743
# ...                        ...                ...                    ...
# 21258                 1.254119          146.88130              15.504479
# 21259                 1.571630          188.38390               7.353333
# 21260                 0.530198           13.51362              53.041104
# 21261                 0.640883           13.51362              31.115202
# 21262                 0.895229           71.75500              43.144000
#
#        std_atomic_mass  ...  wtd_mean_Valence  gmean_Valence  \
# 0            51.968828  ...          2.257143       2.213364
# 1            47.094633  ...          2.257143       1.888175
# 2            51.968828  ...          2.271429       2.213364
# 3            51.968828  ...          2.264286       2.213364
# 4            51.968828  ...          2.242857       2.213364
# ...                ...  ...               ...            ...
# 21258        65.764081  ...          3.555556       3.223710
# 21259        69.232655  ...          2.047619       2.168944
# 21260         6.756810  ...          4.800000       4.472136
# 21261         6.756810  ...          4.690000       4.472136
# 21262        29.905282  ...          4.500000       4.762203
#
#        wtd_gmean_Valence  entropy_Valence  wtd_entropy_Valence  range_Valence  \
# 0               2.219783         1.368922             1.066221              1
# 1               2.210679         1.557113             1.047221              2
# 2               2.232679         1.368922             1.029175              1
# 3               2.226222         1.368922             1.048834              1
# 4               2.206963         1.368922             1.096052              1
# ...                  ...              ...                  ...            ...
# 21258           3.519911         1.377820             0.913658              1
# 21259           2.038991         1.594167             1.337246              1
# 21260           4.781762         0.686962             0.450561              1
# 21261           4.665819         0.686962             0.577601              1
# 21262           4.242641         1.054920             0.970116              3
#
#        wtd_range_Valence  std_Valence  wtd_std_Valence  critical_temp
# 0               1.085714     0.433013         0.437059          29.00
# 1               1.128571     0.632456         0.468606          26.00
# 2               1.114286     0.433013         0.444697          19.00
# 3               1.100000     0.433013         0.440952          22.00
# 4               1.057143     0.433013         0.428809          23.00
# ...                  ...          ...              ...            ...
# 21258           2.168889     0.433013         0.496904           2.44
# 21259           0.904762     0.400000         0.212959         122.10
# 21260           3.200000     0.500000         0.400000           1.98
# 21261           2.210000     0.500000         0.462493           1.84
# 21262           1.800000     1.414214         1.500000          12.80
#
# [21263 rows x 82 columns]

# %% [markdown]
# # Seleccionando los datos para **Entrenamiento, Validación y Prueba**

# %%
from sklearn.model_selection import train_test_split

resto, prueba, resto_clase, prueba_clase = train_test_split(
    superconductivty.data.original[["number_of_elements","mean_atomic_mass","wtd_mean_atomic_mass","gmean_atomic_mass","wtd_gmean_atomic_mass","entropy_atomic_mass","wtd_entropy_atomic_mass","range_atomic_mass","wtd_range_atomic_mass","std_atomic_mass","wtd_std_atomic_mass","mean_fie","wtd_mean_fie","gmean_fie","wtd_gmean_fie","entropy_fie","wtd_entropy_fie","range_fie","wtd_range_fie","std_fie","wtd_std_fie","mean_atomic_radius","wtd_mean_atomic_radius","gmean_atomic_radius","wtd_gmean_atomic_radius","entropy_atomic_radius","wtd_entropy_atomic_radius","range_atomic_radius","wtd_range_atomic_radius","std_atomic_radius","wtd_std_atomic_radius","mean_Density","wtd_mean_Density","gmean_Density","wtd_gmean_Density","entropy_Density","wtd_entropy_Density","range_Density","wtd_range_Density","std_Density","wtd_std_Density","mean_ElectronAffinity","wtd_mean_ElectronAffinity","gmean_ElectronAffinity","wtd_gmean_ElectronAffinity","entropy_ElectronAffinity","wtd_entropy_ElectronAffinity","range_ElectronAffinity","wtd_range_ElectronAffinity","std_ElectronAffinity","wtd_std_ElectronAffinity","mean_FusionHeat","wtd_mean_FusionHeat","gmean_FusionHeat","wtd_gmean_FusionHeat","entropy_FusionHeat","wtd_entropy_FusionHeat","range_FusionHeat","wtd_range_FusionHeat","std_FusionHeat","wtd_std_FusionHeat","mean_ThermalConductivity","wtd_mean_ThermalConductivity","gmean_ThermalConductivity","wtd_gmean_ThermalConductivity","entropy_ThermalConductivity","wtd_entropy_ThermalConductivity","range_ThermalConductivity","wtd_range_ThermalConductivity","std_ThermalConductivity","wtd_std_ThermalConductivity","mean_Valence","wtd_mean_Valence","gmean_Valence","wtd_gmean_Valence","entropy_Valence","wtd_entropy_Valence","range_Valence","wtd_range_Valence","std_Valence","wtd_std_Valence"]],
    superconductivty.data.original["critical_temp"],
    test_size = 0.20)

entrena, valida, entrena_clase, valida_clase = train_test_split(
    resto[["number_of_elements","mean_atomic_mass","wtd_mean_atomic_mass","gmean_atomic_mass","wtd_gmean_atomic_mass","entropy_atomic_mass","wtd_entropy_atomic_mass","range_atomic_mass","wtd_range_atomic_mass","std_atomic_mass","wtd_std_atomic_mass","mean_fie","wtd_mean_fie","gmean_fie","wtd_gmean_fie","entropy_fie","wtd_entropy_fie","range_fie","wtd_range_fie","std_fie","wtd_std_fie","mean_atomic_radius","wtd_mean_atomic_radius","gmean_atomic_radius","wtd_gmean_atomic_radius","entropy_atomic_radius","wtd_entropy_atomic_radius","range_atomic_radius","wtd_range_atomic_radius","std_atomic_radius","wtd_std_atomic_radius","mean_Density","wtd_mean_Density","gmean_Density","wtd_gmean_Density","entropy_Density","wtd_entropy_Density","range_Density","wtd_range_Density","std_Density","wtd_std_Density","mean_ElectronAffinity","wtd_mean_ElectronAffinity","gmean_ElectronAffinity","wtd_gmean_ElectronAffinity","entropy_ElectronAffinity","wtd_entropy_ElectronAffinity","range_ElectronAffinity","wtd_range_ElectronAffinity","std_ElectronAffinity","wtd_std_ElectronAffinity","mean_FusionHeat","wtd_mean_FusionHeat","gmean_FusionHeat","wtd_gmean_FusionHeat","entropy_FusionHeat","wtd_entropy_FusionHeat","range_FusionHeat","wtd_range_FusionHeat","std_FusionHeat","wtd_std_FusionHeat","mean_ThermalConductivity","wtd_mean_ThermalConductivity","gmean_ThermalConductivity","wtd_gmean_ThermalConductivity","entropy_ThermalConductivity","wtd_entropy_ThermalConductivity","range_ThermalConductivity","wtd_range_ThermalConductivity","std_ThermalConductivity","wtd_std_ThermalConductivity","mean_Valence","wtd_mean_Valence","gmean_Valence","wtd_gmean_Valence","entropy_Valence","wtd_entropy_Valence","range_Valence","wtd_range_Valence","std_Valence","wtd_std_Valence"]],
    resto_clase,
    test_size = 0.25)

valida.shape[0]
# Out:
# 4253

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.0)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.5.0)

# %% [markdown]
# # Normalizar datos de entrenamiento

# %%
from sklearn import preprocessing

datos_ent = preprocessing.StandardScaler().fit_transform(entrena)
datos_val = preprocessing.StandardScaler().fit_transform(valida)
datos_prueb = preprocessing.StandardScaler().fit_transform(prueba)

# %% [markdown]
# # Definir el modelo de la red neuronal

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(80, input_dim=datos_ent.shape[1], activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='linear'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'])

# %%
history = model.fit(entrena, entrena_clase, epochs=100, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 191.0386 - mean_absolute_error: 8.8739 - val_loss: 214.0316 - val_mean_absolute_error: 9.3450
# Epoch 2/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 198.1241 - mean_absolute_error: 9.1236 - val_loss: 209.3482 - val_mean_absolute_error: 9.0361
# Epoch 3/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 182.1405 - mean_absolute_error: 8.7009 - val_loss: 231.4222 - val_mean_absolute_error: 10.1206
# Epoch 4/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 189.9278 - mean_absolute_error: 8.9365 - val_loss: 213.4415 - val_mean_absolute_error: 9.3031
# Epoch 5/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 196.5415 - mean_absolute_error: 9.0621 - val_loss: 210.2149 - val_mean_absolute_error: 9.5098
# Epoch 6/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 190.4836 - mean_absolute_error: 9.0068 - val_loss: 240.5025 - val_mean_absolute_error: 10.0837
# Epoch 7/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 185.4117 - mean_absolute_error: 8.7595 - val_loss: 252.0889 - val_mean_absolute_error: 9.9173
# Epoch 8/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 185.0823 - mean_absolute_error: 8.9191 - val_loss: 222.8516 - val_mean_absolute_error: 9.1826
# Epoch 9/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 187.1486 - mean_absolute_error: 8.8104 - val_loss: 230.8030 - val_mean_absolute_error: 9.8891
# Epoch 10/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 194.1685 - mean_absolute_error: 9.2085 - val_loss: 204.2136 - val_mean_absolute_error: 9.3123
# Epoch 11/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 191.4630 - mean_absolute_error: 8.9016 - val_loss: 211.6683 - val_mean_absolute_error: 9.0812
# Epoch 12/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 187.6616 - mean_absolute_error: 8.8534 - val_loss: 210.8330 - val_mean_absolute_error: 8.8979
# Epoch 13/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 188.8784 - mean_absolute_error: 8.7630 - val_loss: 207.2983 - val_mean_absolute_error: 9.0176
# Epoch 14/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 184.8047 - mean_absolute_error: 8.7106 - val_loss: 246.1796 - val_mean_absolute_error: 9.5387
# Epoch 15/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 187.6685 - mean_absolute_error: 8.7945 - val_loss: 216.4867 - val_mean_absolute_error: 9.0666
# Epoch 16/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 185.3281 - mean_absolute_error: 8.7520 - val_loss: 202.8364 - val_mean_absolute_error: 9.0569
# Epoch 17/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 176.1731 - mean_absolute_error: 8.4816 - val_loss: 227.3618 - val_mean_absolute_error: 9.2160
# Epoch 18/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 182.2416 - mean_absolute_error: 8.6985 - val_loss: 218.1448 - val_mean_absolute_error: 9.4388
# Epoch 19/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 192.3728 - mean_absolute_error: 8.8781 - val_loss: 205.7911 - val_mean_absolute_error: 9.0066
# Epoch 20/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 194.8199 - mean_absolute_error: 8.9920 - val_loss: 206.1530 - val_mean_absolute_error: 9.1030
# Epoch 21/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 180.6677 - mean_absolute_error: 8.6475 - val_loss: 212.2245 - val_mean_absolute_error: 9.4229
# Epoch 22/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 191.9336 - mean_absolute_error: 8.9114 - val_loss: 214.3071 - val_mean_absolute_error: 9.2607
# Epoch 23/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 187.7432 - mean_absolute_error: 8.8162 - val_loss: 206.9603 - val_mean_absolute_error: 9.2921
# Epoch 24/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 176.2755 - mean_absolute_error: 8.5175 - val_loss: 199.1145 - val_mean_absolute_error: 8.7629
# Epoch 25/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 168.4706 - mean_absolute_error: 8.3432 - val_loss: 216.2763 - val_mean_absolute_error: 9.3978
# Epoch 26/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 185.2294 - mean_absolute_error: 8.7900 - val_loss: 226.1779 - val_mean_absolute_error: 9.5439
# Epoch 27/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 181.4746 - mean_absolute_error: 8.6385 - val_loss: 203.3061 - val_mean_absolute_error: 9.2787
# Epoch 28/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 178.9066 - mean_absolute_error: 8.6076 - val_loss: 216.4330 - val_mean_absolute_error: 9.5908
# Epoch 29/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 178.5694 - mean_absolute_error: 8.7013 - val_loss: 221.2158 - val_mean_absolute_error: 9.3606
# Epoch 30/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 184.1938 - mean_absolute_error: 8.7132 - val_loss: 234.0966 - val_mean_absolute_error: 10.2723
# Epoch 31/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 185.3255 - mean_absolute_error: 8.7697 - val_loss: 208.4520 - val_mean_absolute_error: 9.1847
# Epoch 32/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 173.8187 - mean_absolute_error: 8.5597 - val_loss: 220.3042 - val_mean_absolute_error: 9.5353
# Epoch 33/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 183.0397 - mean_absolute_error: 8.7211 - val_loss: 220.9880 - val_mean_absolute_error: 9.0578
# Epoch 34/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 187.2564 - mean_absolute_error: 8.8559 - val_loss: 207.2400 - val_mean_absolute_error: 9.0297
# Epoch 35/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 179.6742 - mean_absolute_error: 8.6588 - val_loss: 209.8634 - val_mean_absolute_error: 9.3373
# Epoch 36/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 183.9697 - mean_absolute_error: 8.7148 - val_loss: 215.7558 - val_mean_absolute_error: 9.3970
# Epoch 37/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 170.3382 - mean_absolute_error: 8.3510 - val_loss: 219.3871 - val_mean_absolute_error: 9.2339
# Epoch 38/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 182.6450 - mean_absolute_error: 8.6900 - val_loss: 227.1105 - val_mean_absolute_error: 9.3634
# Epoch 39/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 181.1262 - mean_absolute_error: 8.5826 - val_loss: 199.3331 - val_mean_absolute_error: 9.1665
# Epoch 40/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 169.2007 - mean_absolute_error: 8.4260 - val_loss: 200.6549 - val_mean_absolute_error: 9.1727
# Epoch 41/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 174.9564 - mean_absolute_error: 8.4702 - val_loss: 211.2292 - val_mean_absolute_error: 9.2066
# Epoch 42/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 168.5349 - mean_absolute_error: 8.3445 - val_loss: 219.8694 - val_mean_absolute_error: 9.7418
# Epoch 43/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 177.9769 - mean_absolute_error: 8.6040 - val_loss: 203.3316 - val_mean_absolute_error: 9.4005
# Epoch 44/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 162.2555 - mean_absolute_error: 8.2128 - val_loss: 195.5312 - val_mean_absolute_error: 9.0900
# Epoch 45/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 177.5037 - mean_absolute_error: 8.5000 - val_loss: 234.9760 - val_mean_absolute_error: 9.1715
# Epoch 46/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 181.1971 - mean_absolute_error: 8.5774 - val_loss: 210.3009 - val_mean_absolute_error: 9.4674
# Epoch 47/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 172.7971 - mean_absolute_error: 8.4258 - val_loss: 219.9675 - val_mean_absolute_error: 9.5749
# Epoch 48/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 174.3521 - mean_absolute_error: 8.4522 - val_loss: 203.1377 - val_mean_absolute_error: 9.0644
# Epoch 49/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 176.6129 - mean_absolute_error: 8.4382 - val_loss: 200.6623 - val_mean_absolute_error: 9.0548
# Epoch 50/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 165.3590 - mean_absolute_error: 8.2039 - val_loss: 200.3327 - val_mean_absolute_error: 8.7922
# Epoch 51/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 166.7972 - mean_absolute_error: 8.2019 - val_loss: 199.0812 - val_mean_absolute_error: 8.8950
# Epoch 52/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 178.6512 - mean_absolute_error: 8.4649 - val_loss: 205.3477 - val_mean_absolute_error: 9.2100
# Epoch 53/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 172.3759 - mean_absolute_error: 8.4613 - val_loss: 204.2277 - val_mean_absolute_error: 8.8727
# Epoch 54/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 168.1071 - mean_absolute_error: 8.1413 - val_loss: 200.0324 - val_mean_absolute_error: 9.0229
# Epoch 55/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 162.4733 - mean_absolute_error: 8.1640 - val_loss: 191.5622 - val_mean_absolute_error: 8.8667
# Epoch 56/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 163.2911 - mean_absolute_error: 8.1369 - val_loss: 209.8685 - val_mean_absolute_error: 9.2752
# Epoch 57/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 176.2064 - mean_absolute_error: 8.5223 - val_loss: 221.4207 - val_mean_absolute_error: 9.1021
# Epoch 58/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 160.3958 - mean_absolute_error: 8.0949 - val_loss: 205.8290 - val_mean_absolute_error: 9.3944
# Epoch 59/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 161.6374 - mean_absolute_error: 8.1209 - val_loss: 206.2859 - val_mean_absolute_error: 9.0609
# Epoch 60/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 165.8763 - mean_absolute_error: 8.2330 - val_loss: 206.7133 - val_mean_absolute_error: 9.3323
# Epoch 61/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 169.2565 - mean_absolute_error: 8.3295 - val_loss: 205.3010 - val_mean_absolute_error: 9.4825
# Epoch 62/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 176.0779 - mean_absolute_error: 8.4531 - val_loss: 196.9606 - val_mean_absolute_error: 8.8865
# Epoch 63/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 162.9705 - mean_absolute_error: 8.1102 - val_loss: 204.5676 - val_mean_absolute_error: 9.0623
# Epoch 64/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 167.2636 - mean_absolute_error: 8.2429 - val_loss: 200.5341 - val_mean_absolute_error: 8.9722
# Epoch 65/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 158.2239 - mean_absolute_error: 8.0943 - val_loss: 209.2364 - val_mean_absolute_error: 9.2250
# Epoch 66/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 164.3580 - mean_absolute_error: 8.1374 - val_loss: 243.1667 - val_mean_absolute_error: 9.6837
# Epoch 67/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 169.4330 - mean_absolute_error: 8.3161 - val_loss: 223.3595 - val_mean_absolute_error: 9.2090
# Epoch 68/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 163.6752 - mean_absolute_error: 8.2467 - val_loss: 212.8181 - val_mean_absolute_error: 8.8227
# Epoch 69/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 153.9849 - mean_absolute_error: 7.9349 - val_loss: 201.0976 - val_mean_absolute_error: 8.9802
# Epoch 70/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 151.4484 - mean_absolute_error: 7.9251 - val_loss: 199.4594 - val_mean_absolute_error: 9.1859
# Epoch 71/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 160.8645 - mean_absolute_error: 8.1112 - val_loss: 195.3553 - val_mean_absolute_error: 8.7422
# Epoch 72/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 150.6577 - mean_absolute_error: 7.8597 - val_loss: 207.1697 - val_mean_absolute_error: 8.8368
# Epoch 73/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 159.5784 - mean_absolute_error: 8.0219 - val_loss: 215.8542 - val_mean_absolute_error: 9.1345
# Epoch 74/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 163.0460 - mean_absolute_error: 8.1707 - val_loss: 187.3359 - val_mean_absolute_error: 8.5644
# Epoch 75/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 166.2153 - mean_absolute_error: 8.2105 - val_loss: 195.4160 - val_mean_absolute_error: 8.5733
# Epoch 76/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 165.7182 - mean_absolute_error: 8.1618 - val_loss: 188.4875 - val_mean_absolute_error: 8.6725
# Epoch 77/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 171.2605 - mean_absolute_error: 8.2635 - val_loss: 207.6048 - val_mean_absolute_error: 9.0341
# Epoch 78/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 161.9855 - mean_absolute_error: 8.2091 - val_loss: 212.7870 - val_mean_absolute_error: 9.4290
# Epoch 79/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 170.6798 - mean_absolute_error: 8.3304 - val_loss: 187.2469 - val_mean_absolute_error: 8.8077
# Epoch 80/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 156.9585 - mean_absolute_error: 8.0217 - val_loss: 202.4417 - val_mean_absolute_error: 9.0100
# Epoch 81/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 159.4626 - mean_absolute_error: 8.0380 - val_loss: 204.6955 - val_mean_absolute_error: 9.2924
# Epoch 82/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 161.0019 - mean_absolute_error: 8.0507 - val_loss: 242.4395 - val_mean_absolute_error: 10.0906
# Epoch 83/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 173.4455 - mean_absolute_error: 8.4065 - val_loss: 201.3721 - val_mean_absolute_error: 8.6454
# Epoch 84/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 163.7841 - mean_absolute_error: 8.1480 - val_loss: 199.2476 - val_mean_absolute_error: 9.0800
# Epoch 85/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 159.1558 - mean_absolute_error: 8.0251 - val_loss: 209.8777 - val_mean_absolute_error: 8.6271
# Epoch 86/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 158.6245 - mean_absolute_error: 7.9423 - val_loss: 188.3213 - val_mean_absolute_error: 8.8606
# Epoch 87/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 155.3276 - mean_absolute_error: 7.9818 - val_loss: 187.4662 - val_mean_absolute_error: 8.6832
# Epoch 88/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 161.4406 - mean_absolute_error: 8.0976 - val_loss: 188.9507 - val_mean_absolute_error: 8.5767
# Epoch 89/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 158.2324 - mean_absolute_error: 7.8994 - val_loss: 201.0299 - val_mean_absolute_error: 8.9578
# Epoch 90/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 153.7098 - mean_absolute_error: 7.7862 - val_loss: 210.8357 - val_mean_absolute_error: 9.3588
# Epoch 91/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 149.0290 - mean_absolute_error: 7.7301 - val_loss: 194.0361 - val_mean_absolute_error: 8.8948
# Epoch 92/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 165.0622 - mean_absolute_error: 8.2066 - val_loss: 193.0111 - val_mean_absolute_error: 8.8613
# Epoch 93/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 157.8890 - mean_absolute_error: 7.9947 - val_loss: 191.2060 - val_mean_absolute_error: 8.5030
# Epoch 94/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 154.1314 - mean_absolute_error: 7.8473 - val_loss: 194.1752 - val_mean_absolute_error: 8.6306
# Epoch 95/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 158.3008 - mean_absolute_error: 8.0408 - val_loss: 202.8766 - val_mean_absolute_error: 9.0898
# Epoch 96/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 160.5353 - mean_absolute_error: 8.0700 - val_loss: 189.8542 - val_mean_absolute_error: 8.9808
# Epoch 97/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 143.9643 - mean_absolute_error: 7.6570 - val_loss: 192.5282 - val_mean_absolute_error: 8.7565
# Epoch 98/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 160.5311 - mean_absolute_error: 8.0810 - val_loss: 194.5583 - val_mean_absolute_error: 9.0888
# Epoch 99/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 159.0869 - mean_absolute_error: 8.0126 - val_loss: 186.0323 - val_mean_absolute_error: 8.7541
# Epoch 100/100
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 148.3604 - mean_absolute_error: 7.6979 - val_loss: 232.1421 - val_mean_absolute_error: 9.2639

# %% [markdown]
# # Visualizar el Proceso de Entrenamiento

# %%
import matplotlib.pyplot as plt

# Graficar la pérdida y el MAE durante el entrenamiento
plt.figure(figsize=(12, 4))

# Pérdida
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Pérdida de entrenamiento')
plt.plot(history.history['val_loss'], label='Pérdida de validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.title('Pérdida durante el entrenamiento')

# MAE
plt.subplot(1, 2, 2)
plt.plot(history.history['mean_absolute_error'], label='MAE de entrenamiento')
plt.plot(history.history['val_mean_absolute_error'], label='MAE de validación')
plt.xlabel('Épocas')
plt.ylabel('MAE')
plt.legend()
plt.title('MAE durante el entrenamiento')

plt.show()

# %% [markdown]
# # Evaluar el Modelo

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Hacer predicciones
predictions = model.predict(datos_prueb)

# Calcular MSE
mse = mean_squared_error(prueba_clase, predictions)
print(f'Error Cuadrático Medio (MSE): {mse}')

# Calcular MAE
mae = mean_absolute_error(prueba_clase, predictions)
print(f'Error Absoluto Medio (MAE): {mae}')

# Calcular R²
r2 = r2_score(prueba_clase, predictions)
print(f'Coeficiente de Determinación (R²): {r2}')
# Out:
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Error Cuadrático Medio (MSE): 2043.0322930153486
# Error Absoluto Medio (MAE): 30.945461534539408
# Coeficiente de Determinación (R²): -0.7771587167614269
